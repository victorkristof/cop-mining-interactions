# %%
import urllib.request
import re
from bs4 import BeautifulSoup
from dateutil.parser import parse

# %%
# Download the specific page to be able to extract information from it 

page = urllib.request.urlopen('https://enb.iisd.org/enb/vol12/').read()
soup = BeautifulSoup(page)

#Global Variable

month = {'January':1,'February':2,'March':3,'April':4,'May':5,'June':6,'July':7,'August':8,'September':9,'October':10,'November':11,'December':12}

# %%
# Function that extracts a date from a given string by returning a tuple of int (day,month,year)

def extract_date(sdate):
    if(extract_number(sdate) == None ):
        return sdate
    
    m = re.findall('\d{4}|\d{2}|January|February|March|April|May|June|July|August|September|October|November|December|\d{1}',sdate)
    
    if(len(m)==0):
        d=0
    if(len(m)==5):
        d = (int(m[0]),month[m[1]],int(m[len(m)-1]))
    if(len(m)==4):
        d = (int(m[0]),month[m[2]],int(m[len(m)-1]))
    if(len(m)==3):
        d = (int(m[0]),month[m[1]],int(m[2]))
    
    d_str = str(d[2])+"-"+str(d[1])+"-"+str(d[0])
    
    return d_str

# %%
# Function that extracts digit from a given string and return an int 

def extract_number(sname):
    for i in sname.split():
        
        if i.isdigit():
            return int(i)

# %%
# Function that helps to compose and order the list. Returns an ordered, by date, list who contains all the COPs with their attributes

def compute_list(list_string):
    list_cop = []

    for s in list_string:
        l = s.split('|')
        list_cop.append((extract_number(l[0]),extract_date(l[1]),l[2]))
        
    list_cop.sort(key=lambda a: a[0], reverse=False)

    return list_cop

# %%
# Function that extract the list of all the COPs from a webpage and return a list containing all the COPs with their number, date and place

def extract_list_cops(soup):
    
    # find all the different COPs (not named the same way)
    
    #Case 1 :"COP"+"\s"+"\d"+"\s"+"."+"\s"  // COP 1-9
    list = soup.find_all(string=re.compile("COP"+"\s"+"\d"+"\s"+"."+"\s"))

    #Case 2 : "COP"+"\s"+"[1-2][0-9]"+"\s"+"."+"\s"+"\d" // COP 10,23,24,25
    list += soup.find_all(string=re.compile("COP"+"\s"+"[1-2][0-9]"+"\s"+"."+"\s"+"\d"))
    
    #Case 3 :"COP"+"\s"+"[1-2][0-9]"+"\s"+"."+"\s"+"CMP"+"\s"+"\d"+"."+"." // COP 11,12,13,14,15,16,21,22
    list_2 = soup.find_all(string=re.compile("COP"+"\s"+"[1-2][0-9]"+"\s"+"."+"\s"+"CMP"+"\s"+"\d+"+"\s"))

    # Case 4 : "COP"+"\s"+"[1-2][0-9]"+"\s"+"."+"\s"+"CMP"+"\d"+"\s" //COP 17,18,19
    list_3 = soup.find_all(string=re.compile("COP"+"\s"+"[1-2][0-9]"+"\s"+"."+"\s"+"CMP"+"\d+"+"\s"))
    
    # Clean the lists to have all the same structure
    # Clean list_2
    for i in range(len(list_2)) :
        list_2[i] =  re.sub("- CMP"+"\s"+"."+".", '', list_2[i])

    # Clean list_3
    for i in range(len(list_3)) :
        list_3[i] =  re.sub("- CMP"+".", '', list_3[i])
    
    #combine all the lists
    list += list_2
    list += list_3
   
    return compute_list(list)

# %%
# Function that extract all the issues for each COPs and return a list in which for each COPs we have the issues corresponding with their number  date and html link 

def extract_details_cops(soup):
    
    detail_COPs = []
    
    for row in soup.find_all("tr"):
        cop_num ='to be fixed'
        for col in row.find_all('td'):
        
            if("Issue" in col.string):
                a = row.find_previous_sibling('tr')
                b= a.find_next('th')
                detail = []
                issue_start = 0
                if("</h3>COP" in str(b) and not("BIS" in str(b))):
                    date_td = col.find_next_sibling('td')
                    
                    #while(col.find_next_sibling('tr').)
                    #while("Summary" != date_td.string and "Summary and Analysis" != date_td.string):
                    while( "<a name=" not in str(date_td.find_next('tr'))):              
                
                        ## extract issue number
                        issue = int(re.findall('\d+',col.string)[0])
                        if(issue - issue_start>1):
                            issue_type = 'First'
                        else:
                            issue_type = 'Issue'
                        
                        pdf_td = date_td.find_next_sibling('td')
                        ## extract html link
                        html_td = pdf_td.find_next_sibling('td')
                        html = 'https://enb.iisd.org'+html_td.find('a',href=True)['href']
                    
                        ## extract date
                        s = date_td.string
                        date = extract_date(s)    
                        
                        ##prepare for the next issue 
                        if(pdf_td.find_next('tr') == None):
                            detail.append((cop_num,issue,date,html,'Summary'))
                            detail_COPs.append(detail)
                            return detail_COPs
                        else:
                            col = pdf_td.find_next('tr').find_next('td')
                            date_td = col.find_next_sibling('td')
                            issue_start = issue
                       
                        ##add the issue into the list
                        detail.append((cop_num,issue,date,html,issue_type))
                        
                    if( "<a name=" in str(date_td.find_next('tr'))): 
                    ## extract issue number
                        issue = int(re.findall('\d+',col.string)[0])
                        
                        pdf_td = date_td.find_next_sibling('td')
                    ## extract html link
                        html_td = pdf_td.find_next_sibling('td')
                        html = 'https://enb.iisd.org'+html_td.find('a',href=True)['href']
                    
                    ## extract date
                        s = date_td.string
                        date = extract_date(s)
                        detail.append((cop_num,issue,date,html,'Summary'))
                    
                    
                    
                    detail_COPs.append(detail)

# %%
listed = extract_details_cops(soup)

for cop in listed:
    for issue in cop:
        print(issue)
# Out:
# ('to be fixed', 12, '1995-3-28', 'https://enb.iisd.org/vol12/1212000e.html', 'First')
# ('to be fixed', 13, '1995-3-29', 'https://enb.iisd.org/vol12/1213000e.html', 'Issue')
# ('to be fixed', 14, '1995-3-30', 'https://enb.iisd.org/vol12/1214000e.html', 'Issue')
# ('to be fixed', 15, '1995-3-31', 'https://enb.iisd.org/vol12/1215000e.html', 'Issue')
# ('to be fixed', 16, '1995-4-3', 'https://enb.iisd.org/vol12/1216000e.html', 'Issue')
# ('to be fixed', 17, '1995-4-4', 'https://enb.iisd.org/vol12/1217000e.html', 'Issue')
# ('to be fixed', 18, '1995-4-5', 'https://enb.iisd.org/vol12/1218000e.html', 'Issue')
# ('to be fixed', 19, '1995-4-6', 'https://enb.iisd.org/vol12/1219000e.html', 'Issue')
# ('to be fixed', 20, '1995-4-7', 'https://enb.iisd.org/vol12/1220000e.html', 'Issue')
# ('to be fixed', 21, 'Summary', 'https://enb.iisd.org/vol12/1221000e.html', 'Summary')
# ('to be fixed', 28, '1996-7-8', 'https://enb.iisd.org/vol12/1228000e.html', 'First')
# ('to be fixed', 29, '1996-7-9', 'https://enb.iisd.org/vol12/1229000e.html', 'Issue')
# ('to be fixed', 30, '1996-7-10', 'https://enb.iisd.org/vol12/1230000e.html', 'Issue')
# ('to be fixed', 31, '1996-7-11', 'https://enb.iisd.org/vol12/1231000e.html', 'Issue')
# ('to be fixed', 32, '1996-7-12', 'https://enb.iisd.org/vol12/1232000e.html', 'Issue')
# ('to be fixed', 33, '1996-7-15', 'https://enb.iisd.org/vol12/1233000e.html', 'Issue')
# ('to be fixed', 34, '1996-7-16', 'https://enb.iisd.org/vol12/1234000e.html', 'Issue')
# ('to be fixed', 35, '1996-7-17', 'https://enb.iisd.org/vol12/1235000e.html', 'Issue')
# ('to be fixed', 36, '1996-7-18', 'https://enb.iisd.org/vol12/1236000e.html', 'Issue')
# ('to be fixed', 37, '1996-7-19', 'https://enb.iisd.org/vol12/1237000e.html', 'Issue')
# ('to be fixed', 38, 'Summary', 'https://enb.iisd.org/vol12/1238000e.html', 'Summary')
# ('to be fixed', 67, '1997-12-1', 'https://enb.iisd.org/vol12/enb1267e.html', 'First')
# ('to be fixed', 68, '1997-12-2', 'https://enb.iisd.org/vol12/enb1268e.html', 'Issue')
# ('to be fixed', 69, '1997-12-3', 'https://enb.iisd.org/vol12/enb1269e.html', 'Issue')
# ('to be fixed', 70, '1997-12-4', 'https://enb.iisd.org/vol12/enb1270e.html', 'Issue')
# ('to be fixed', 71, '1997-12-5', 'https://enb.iisd.org/vol12/enb1271e.html', 'Issue')
# ('to be fixed', 72, '1997-12-6', 'https://enb.iisd.org/vol12/enb1272e.html', 'Issue')
# ('to be fixed', 73, '1997-12-8', 'https://enb.iisd.org/vol12/enb1273e.html', 'Issue')
# ('to be fixed', 74, '1997-12-9', 'https://enb.iisd.org/vol12/enb1274e.html', 'Issue')
# ('to be fixed', 75, '1997-12-10', 'https://enb.iisd.org/vol12/enb1275e.html', 'Issue')
# ('to be fixed', 76, 'Summary', 'https://enb.iisd.org/vol12/enb1276e.html', 'Summary')
# ('to be fixed', 87, '1998-11-2', 'https://enb.iisd.org/vol12/enb1287e.html', 'First')
# ('to be fixed', 88, '1998-11-3', 'https://enb.iisd.org/vol12/enb1288e.html', 'Issue')
# ('to be fixed', 89, '1998-11-4', 'https://enb.iisd.org/vol12/enb1289e.html', 'Issue')
# ('to be fixed', 90, '1998-11-5', 'https://enb.iisd.org/vol12/enb1290e.html', 'Issue')
# ('to be fixed', 91, '1998-11-6', 'https://enb.iisd.org/vol12/enb1291e.html', 'Issue')
# ('to be fixed', 92, '1998-11-9', 'https://enb.iisd.org/vol12/enb1292e.html', 'Issue')
# ('to be fixed', 93, '1998-11-10', 'https://enb.iisd.org/vol12/enb1293e.html', 'Issue')
# ('to be fixed', 94, '1998-11-11', 'https://enb.iisd.org/vol12/enb1294e.html', 'Issue')
# ('to be fixed', 95, '1998-11-12', 'https://enb.iisd.org/vol12/enb1295e.html', 'Issue')
# ('to be fixed', 96, '1998-11-13', 'https://enb.iisd.org/vol12/enb1296e.html', 'Issue')
# ('to be fixed', 97, 'Summary', 'https://enb.iisd.org/vol12/enb1297e.html', 'Summary')
# ('to be fixed', 112, '1999-10-25', 'https://enb.iisd.org/vol12/enb12112e.html', 'First')
# ('to be fixed', 113, '1999-10-26', 'https://enb.iisd.org/vol12/enb12113e.html', 'Issue')
# ('to be fixed', 114, '1999-10-27', 'https://enb.iisd.org/vol12/enb12114e.html', 'Issue')
# ('to be fixed', 115, '1999-10-28', 'https://enb.iisd.org/vol12/enb12115e.html', 'Issue')
# ('to be fixed', 116, '1999-10-29', 'https://enb.iisd.org/vol12/enb12116e.html', 'Issue')
# ('to be fixed', 117, '1999-10-30', 'https://enb.iisd.org/vol12/enb12117e.html', 'Issue')
# ('to be fixed', 118, '1999-11-1', 'https://enb.iisd.org/vol12/enb12118e.html', 'Issue')
# ('to be fixed', 119, '1999-11-2', 'https://enb.iisd.org/vol12/enb12119e.html', 'Issue')
# ('to be fixed', 120, '1999-11-3', 'https://enb.iisd.org/vol12/enb12120e.html', 'Issue')
# ('to be fixed', 121, '1999-11-4', 'https://enb.iisd.org/vol12/enb12121e.html', 'Issue')
# ('to be fixed', 122, '1999-11-5', 'https://enb.iisd.org/vol12/enb12122e.html', 'Issue')
# ('to be fixed', 123, 'Summary', 'https://enb.iisd.org/vol12/enb12123e.html', 'Summary')
# ('to be fixed', 152, '2000-11-13', 'https://enb.iisd.org/vol12/enb12152e.html', 'First')
# ('to be fixed', 153, '2000-11-14', 'https://enb.iisd.org/vol12/enb12153e.html', 'Issue')
# ('to be fixed', 154, '2000-11-15', 'https://enb.iisd.org/vol12/enb12154e.html', 'Issue')
# ('to be fixed', 155, '2000-11-16', 'https://enb.iisd.org/vol12/enb12155e.html', 'Issue')
# ('to be fixed', 156, '2000-11-17', 'https://enb.iisd.org/vol12/enb12156e.html', 'Issue')
# ('to be fixed', 157, '2000-11-18', 'https://enb.iisd.org/vol12/enb12157e.html', 'Issue')
# ('to be fixed', 158, '2000-11-20', 'https://enb.iisd.org/vol12/enb12158e.html', 'Issue')
# ('to be fixed', 159, '2000-11-21', 'https://enb.iisd.org/vol12/enb12159e.html', 'Issue')
# ('to be fixed', 160, '2000-11-22', 'https://enb.iisd.org/vol12/enb12160e.html', 'Issue')
# ('to be fixed', 161, '2000-11-23', 'https://enb.iisd.org/vol12/enb12161e.html', 'Issue')
# ('to be fixed', 162, '2000-11-24', 'https://enb.iisd.org/vol12/enb12162e.html', 'Issue')
# ('to be fixed', 163, 'Summary', 'https://enb.iisd.org/vol12/enb12163e.html', 'Summary')
# ('to be fixed', 178, '2001-10-29', 'https://enb.iisd.org/vol12/enb12178e.html', 'First')
# ('to be fixed', 179, '2001-10-30', 'https://enb.iisd.org/vol12/enb12179e.html', 'Issue')
# ('to be fixed', 180, '2001-10-31', 'https://enb.iisd.org/vol12/enb12180e.html', 'Issue')
# ('to be fixed', 181, '2001-11-1', 'https://enb.iisd.org/vol12/enb12181e.html', 'Issue')
# ('to be fixed', 182, '2001-11-2', 'https://enb.iisd.org/vol12/enb12182e.html', 'Issue')
# ('to be fixed', 183, '2001-11-3', 'https://enb.iisd.org/vol12/enb12183e.html', 'Issue')
# ('to be fixed', 184, '2001-11-5', 'https://enb.iisd.org/vol12/enb12184e.html', 'Issue')
# ('to be fixed', 185, '2001-11-6', 'https://enb.iisd.org/vol12/enb12185e.html', 'Issue')
# ('to be fixed', 186, '2001-11-7', 'https://enb.iisd.org/vol12/enb12186e.html', 'Issue')
# ('to be fixed', 187, '2001-11-8', 'https://enb.iisd.org/vol12/enb12187e.html', 'Issue')
# ('to be fixed', 188, '2001-11-9', 'https://enb.iisd.org/vol12/enb12188e.html', 'Issue')
# ('to be fixed', 189, 'Summary', 'https://enb.iisd.org/vol12/enb12189e.html', 'Summary')
# ('to be fixed', 201, '2002-10-23', 'https://enb.iisd.org/vol12/enb12201e.html', 'First')
# ('to be fixed', 202, '2002-10-24', 'https://enb.iisd.org/vol12/enb12202e.html', 'Issue')
# ('to be fixed', 203, '2002-10-25', 'https://enb.iisd.org/vol12/enb12203e.html', 'Issue')
# ('to be fixed', 204, '2002-10-26', 'https://enb.iisd.org/vol12/enb12204e.html', 'Issue')
# ('to be fixed', 205, '2002-10-29', 'https://enb.iisd.org/vol12/enb12205e.html', 'Issue')
# ('to be fixed', 206, '2002-10-30', 'https://enb.iisd.org/vol12/enb12206e.html', 'Issue')
# ('to be fixed', 207, '2002-10-31', 'https://enb.iisd.org/vol12/enb12207e.html', 'Issue')
# ('to be fixed', 208, '2002-11-1', 'https://enb.iisd.org/vol12/enb12208e.html', 'Issue')
# ('to be fixed', 209, 'Summary', 'https://enb.iisd.org/vol12/enb12209e.html', 'Summary')
# ('to be fixed', 221, '2003-12-1', 'https://enb.iisd.org/vol12/enb12221e.html', 'First')
# ('to be fixed', 222, '2003-12-2', 'https://enb.iisd.org/vol12/enb12222e.html', 'Issue')
# ('to be fixed', 223, '2003-12-3', 'https://enb.iisd.org/vol12/enb12223e.html', 'Issue')
# ('to be fixed', 224, '2003-12-4', 'https://enb.iisd.org/vol12/enb12224e.html', 'Issue')
# ('to be fixed', 225, '2003-12-5', 'https://enb.iisd.org/vol12/enb12225e.html', 'Issue')
# ('to be fixed', 226, '2003-12-6', 'https://enb.iisd.org/vol12/enb12226e.html', 'Issue')
# ('to be fixed', 227, '2003-12-7', 'https://enb.iisd.org/vol12/enb12227e.html', 'Issue')
# ('to be fixed', 228, '2003-12-10', 'https://enb.iisd.org/vol12/enb12228e.html', 'Issue')
# ('to be fixed', 229, '2003-12-11', 'https://enb.iisd.org/vol12/enb12229e.html', 'Issue')
# ('to be fixed', 230, '2003-12-12', 'https://enb.iisd.org/vol12/enb12230e.html', 'Issue')
# ('to be fixed', 231, 'Summary', 'https://enb.iisd.org/vol12/enb12231e.html', 'Summary')
# ('to be fixed', 249, '2004-12-6', 'https://enb.iisd.org/vol12/enb12249e.html', 'First')
# ('to be fixed', 250, '2004-12-7', 'https://enb.iisd.org/vol12/enb12250e.html', 'Issue')
# ('to be fixed', 251, '2004-12-8', 'https://enb.iisd.org/vol12/enb12251e.html', 'Issue')
# ('to be fixed', 252, '2004-12-9', 'https://enb.iisd.org/vol12/enb12252e.html', 'Issue')
# ('to be fixed', 253, '2004-12-10', 'https://enb.iisd.org/vol12/enb12253e.html', 'Issue')
# ('to be fixed', 254, '2004-12-11', 'https://enb.iisd.org/vol12/enb12254e.html', 'Issue')
# ('to be fixed', 255, '2004-12-13', 'https://enb.iisd.org/vol12/enb12255e.html', 'Issue')
# ('to be fixed', 256, '2004-12-14', 'https://enb.iisd.org/vol12/enb12256e.html', 'Issue')
# ('to be fixed', 257, '2004-12-15', 'https://enb.iisd.org/vol12/enb12257e.html', 'Issue')
# ('to be fixed', 258, '2004-12-16', 'https://enb.iisd.org/vol12/enb12258e.html', 'Issue')
# ('to be fixed', 259, '2004-12-17', 'https://enb.iisd.org/vol12/enb12259e.html', 'Issue')
# ('to be fixed', 260, 'Summary', 'https://enb.iisd.org/vol12/enb12260e.html', 'Summary')
# ('to be fixed', 280, '2005-11-28', 'https://enb.iisd.org/vol12/enb12280e.html', 'First')
# ('to be fixed', 281, '2005-11-29', 'https://enb.iisd.org/vol12/enb12281e.html', 'Issue')
# ('to be fixed', 282, '2005-11-30', 'https://enb.iisd.org/vol12/enb12282e.html', 'Issue')
# ('to be fixed', 283, '2005-12-1', 'https://enb.iisd.org/vol12/enb12283e.html', 'Issue')
# ('to be fixed', 284, '2005-12-2', 'https://enb.iisd.org/vol12/enb12284e.html', 'Issue')
# ('to be fixed', 285, '2005-12-3', 'https://enb.iisd.org/vol12/enb12285e.html', 'Issue')
# ('to be fixed', 286, '2005-12-5', 'https://enb.iisd.org/vol12/enb12286e.html', 'Issue')
# ('to be fixed', 287, '2005-12-6', 'https://enb.iisd.org/vol12/enb12287e.html', 'Issue')
# ('to be fixed', 288, '2005-12-7', 'https://enb.iisd.org/vol12/enb12288e.html', 'Issue')
# ('to be fixed', 289, '2005-12-8', 'https://enb.iisd.org/vol12/enb12289e.html', 'Issue')
# ('to be fixed', 290, '2005-12-9', 'https://enb.iisd.org/vol12/enb12290e.html', 'Issue')
# ('to be fixed', 291, 'Summary', 'https://enb.iisd.org/vol12/enb12291e.html', 'Summary')
# ('to be fixed', 307, '2006-11-6', 'https://enb.iisd.org/vol12/enb12307e.html', 'First')
# ('to be fixed', 308, '2006-11-7', 'https://enb.iisd.org/vol12/enb12308e.html', 'Issue')
# ('to be fixed', 309, '2006-11-8', 'https://enb.iisd.org/vol12/enb12309e.html', 'Issue')
# ('to be fixed', 310, '2006-11-9', 'https://enb.iisd.org/vol12/enb12310e.html', 'Issue')
# ('to be fixed', 311, '2006-11-10', 'https://enb.iisd.org/vol12/enb12311e.html', 'Issue')
# ('to be fixed', 312, '2006-11-11', 'https://enb.iisd.org/vol12/enb12312e.html', 'Issue')
# ('to be fixed', 313, '2006-11-13', 'https://enb.iisd.org/vol12/enb12313e.html', 'Issue')
# ('to be fixed', 314, '2006-11-14', 'https://enb.iisd.org/vol12/enb12314e.html', 'Issue')
# ('to be fixed', 315, '2006-11-15', 'https://enb.iisd.org/vol12/enb12315e.html', 'Issue')
# ('to be fixed', 316, '2006-11-16', 'https://enb.iisd.org/vol12/enb12316e.html', 'Issue')
# ('to be fixed', 317, '2006-11-17', 'https://enb.iisd.org/vol12/enb12317e.html', 'Issue')
# ('to be fixed', 318, 'Summary', 'https://enb.iisd.org/vol12/enb12318e.html', 'Summary')
# ('to be fixed', 343, '2007-12-3', 'https://enb.iisd.org/vol12/enb12343e.html', 'First')
# ('to be fixed', 344, '2007-12-4', 'https://enb.iisd.org/vol12/enb12344e.html', 'Issue')
# ('to be fixed', 345, '2007-12-5', 'https://enb.iisd.org/vol12/enb12345e.html', 'Issue')
# ('to be fixed', 346, '2007-12-6', 'https://enb.iisd.org/vol12/enb12346e.html', 'Issue')
# ('to be fixed', 347, '2007-12-7', 'https://enb.iisd.org/vol12/enb12347e.html', 'Issue')
# ('to be fixed', 348, '2007-12-8', 'https://enb.iisd.org/vol12/enb12348e.html', 'Issue')
# ('to be fixed', 349, '2007-12-10', 'https://enb.iisd.org/vol12/enb12349e.html', 'Issue')
# ('to be fixed', 350, '2007-12-11', 'https://enb.iisd.org/vol12/enb12350e.html', 'Issue')
# ('to be fixed', 351, '2007-12-12', 'https://enb.iisd.org/vol12/enb12351e.html', 'Issue')
# ('to be fixed', 352, '2007-12-13', 'https://enb.iisd.org/vol12/enb12352e.html', 'Issue')
# ('to be fixed', 353, '2007-12-14', 'https://enb.iisd.org/vol12/enb12353e.html', 'Issue')
# ('to be fixed', 354, 'Summary', 'https://enb.iisd.org/vol12/enb12354e.html', 'Summary')
# ('to be fixed', 385, '2008-12-1', 'https://enb.iisd.org/vol12/enb12385e.html', 'First')
# ('to be fixed', 386, '2008-12-2', 'https://enb.iisd.org/vol12/enb12386e.html', 'Issue')
# ('to be fixed', 387, '2008-12-3', 'https://enb.iisd.org/vol12/enb12387e.html', 'Issue')
# ('to be fixed', 388, '2008-12-4', 'https://enb.iisd.org/vol12/enb12388e.html', 'Issue')
# ('to be fixed', 389, '2008-12-5', 'https://enb.iisd.org/vol12/enb12389e.html', 'Issue')
# ('to be fixed', 390, '2008-12-6', 'https://enb.iisd.org/vol12/enb12390e.html', 'Issue')
# ('to be fixed', 391, '2008-12-9', 'https://enb.iisd.org/vol12/enb12391e.html', 'Issue')
# ('to be fixed', 392, '2008-12-10', 'https://enb.iisd.org/vol12/enb12392e.html', 'Issue')
# ('to be fixed', 393, '2008-12-11', 'https://enb.iisd.org/vol12/enb12393e.html', 'Issue')
# ('to be fixed', 394, '2008-12-12', 'https://enb.iisd.org/vol12/enb12394e.html', 'Issue')
# ('to be fixed', 395, 'Summary', 'https://enb.iisd.org/vol12/enb12395e.html', 'Summary')
# ('to be fixed', 448, '2009-12-7', 'https://enb.iisd.org/vol12/enb12448e.html', 'First')
# ('to be fixed', 449, '2009-12-8', 'https://enb.iisd.org/vol12/enb12449e.html', 'Issue')
# ('to be fixed', 450, '2009-12-9', 'https://enb.iisd.org/vol12/enb12450e.html', 'Issue')
# ('to be fixed', 451, '2009-12-10', 'https://enb.iisd.org/vol12/enb12451e.html', 'Issue')
# ('to be fixed', 452, '2009-12-11', 'https://enb.iisd.org/vol12/enb12452e.html', 'Issue')
# ('to be fixed', 453, '2009-12-12', 'https://enb.iisd.org/vol12/enb12453e.html', 'Issue')
# ('to be fixed', 454, '2009-12-14', 'https://enb.iisd.org/vol12/enb12454e.html', 'Issue')
# ('to be fixed', 455, '2009-12-15', 'https://enb.iisd.org/vol12/enb12455e.html', 'Issue')
# ('to be fixed', 456, '2009-12-16', 'https://enb.iisd.org/vol12/enb12456e.html', 'Issue')
# ('to be fixed', 457, '2009-12-17', 'https://enb.iisd.org/vol12/enb12457e.html', 'Issue')
# ('to be fixed', 458, '2009-12-18', 'https://enb.iisd.org/vol12/enb12458e.html', 'Issue')
# ('to be fixed', 459, 'Summary', 'https://enb.iisd.org/vol12/enb12459e.html', 'Summary')
# ('to be fixed', 487, '2010-11-29', 'https://enb.iisd.org/vol12/enb12487e.html', 'First')
# ('to be fixed', 488, '2010-11-30', 'https://enb.iisd.org/vol12/enb12488e.html', 'Issue')
# ('to be fixed', 489, '2010-12-1', 'https://enb.iisd.org/vol12/enb12489e.html', 'Issue')
# ('to be fixed', 490, '2010-12-2', 'https://enb.iisd.org/vol12/enb12490e.html', 'Issue')
# ('to be fixed', 491, '2010-12-3', 'https://enb.iisd.org/vol12/enb12491e.html', 'Issue')
# ('to be fixed', 492, '2010-12-4', 'https://enb.iisd.org/vol12/enb12492e.html', 'Issue')
# ('to be fixed', 493, '2010-12-6', 'https://enb.iisd.org/vol12/enb12493e.html', 'Issue')
# ('to be fixed', 494, '2010-12-7', 'https://enb.iisd.org/vol12/enb12494e.html', 'Issue')
# ('to be fixed', 495, '2010-12-8', 'https://enb.iisd.org/vol12/enb12495e.html', 'Issue')
# ('to be fixed', 496, '2010-12-9', 'https://enb.iisd.org/vol12/enb12496e.html', 'Issue')
# ('to be fixed', 497, '2010-12-10', 'https://enb.iisd.org/vol12/enb12497e.html', 'Issue')
# ('to be fixed', 498, 'Summary', 'https://enb.iisd.org/vol12/enb12498e.html', 'Summary')
# ('to be fixed', 523, '2011-11-28', 'https://enb.iisd.org/vol12/enb12523e.html', 'First')
# ('to be fixed', 524, '2011-11-29', 'https://enb.iisd.org/vol12/enb12524e.html', 'Issue')
# ('to be fixed', 525, '2011-11-30', 'https://enb.iisd.org/vol12/enb12525e.html', 'Issue')
# ('to be fixed', 526, '2011-12-1', 'https://enb.iisd.org/vol12/enb12526e.html', 'Issue')
# ('to be fixed', 527, '2011-12-2', 'https://enb.iisd.org/vol12/enb12527e.html', 'Issue')
# ('to be fixed', 528, '2011-12-3', 'https://enb.iisd.org/vol12/enb12528e.html', 'Issue')
# ('to be fixed', 529, '2011-12-5', 'https://enb.iisd.org/vol12/enb12529e.html', 'Issue')
# ('to be fixed', 530, '2011-12-6', 'https://enb.iisd.org/vol12/enb12530e.html', 'Issue')
# ('to be fixed', 531, '2011-12-7', 'https://enb.iisd.org/vol12/enb12531e.html', 'Issue')
# ('to be fixed', 532, '2011-12-8', 'https://enb.iisd.org/vol12/enb12532e.html', 'Issue')
# ('to be fixed', 533, '2011-12-9', 'https://enb.iisd.org/vol12/enb12533e.html', 'Issue')
# ('to be fixed', 534, 'Summary', 'https://enb.iisd.org/vol12/enb12534e.html', 'Summary')
# ('to be fixed', 556, '2012-11-26', 'https://enb.iisd.org/vol12/enb12556e.html', 'First')
# ('to be fixed', 557, '2012-11-27', 'https://enb.iisd.org/vol12/enb12557e.html', 'Issue')
# ('to be fixed', 558, '2012-11-28', 'https://enb.iisd.org/vol12/enb12558e.html', 'Issue')
# ('to be fixed', 559, '2012-11-29', 'https://enb.iisd.org/vol12/enb12559e.html', 'Issue')
# ('to be fixed', 560, '2012-11-30', 'https://enb.iisd.org/vol12/enb12560e.html', 'Issue')
# ('to be fixed', 561, '2012-12-1', 'https://enb.iisd.org/vol12/enb12561e.html', 'Issue')
# ('to be fixed', 562, '2012-12-3', 'https://enb.iisd.org/vol12/enb12562e.html', 'Issue')
# ('to be fixed', 563, '2012-12-4', 'https://enb.iisd.org/vol12/enb12563e.html', 'Issue')
# ('to be fixed', 564, '2012-12-5', 'https://enb.iisd.org/vol12/enb12564e.html', 'Issue')
# ('to be fixed', 565, '2012-12-6', 'https://enb.iisd.org/vol12/enb12565e.html', 'Issue')
# ('to be fixed', 566, '2012-12-7', 'https://enb.iisd.org/vol12/enb12566e.html', 'Issue')
# ('to be fixed', 567, 'Summary', 'https://enb.iisd.org/vol12/enb12567e.html', 'Summary')
# ('to be fixed', 583, '2013-11-11', 'https://enb.iisd.org/vol12/enb12583e.html', 'First')
# ('to be fixed', 584, '2013-11-12', 'https://enb.iisd.org/vol12/enb12584e.html', 'Issue')
# ('to be fixed', 585, '2013-11-13', 'https://enb.iisd.org/vol12/enb12585e.html', 'Issue')
# ('to be fixed', 586, '2013-11-14', 'https://enb.iisd.org/vol12/enb12586e.html', 'Issue')
# ('to be fixed', 587, '2013-11-15', 'https://enb.iisd.org/vol12/enb12587e.html', 'Issue')
# ('to be fixed', 588, '2013-11-16', 'https://enb.iisd.org/vol12/enb12588e.html', 'Issue')
# ('to be fixed', 589, '2013-11-18', 'https://enb.iisd.org/vol12/enb12589e.html', 'Issue')
# ('to be fixed', 590, '2013-11-19', 'https://enb.iisd.org/vol12/enb12590e.html', 'Issue')
# ('to be fixed', 591, '2013-11-20', 'https://enb.iisd.org/vol12/enb12591e.html', 'Issue')
# ('to be fixed', 592, '2013-11-21', 'https://enb.iisd.org/vol12/enb12592e.html', 'Issue')
# ('to be fixed', 593, '2013-11-22', 'https://enb.iisd.org/vol12/enb12593e.html', 'Issue')
# ('to be fixed', 594, 'Summary', 'https://enb.iisd.org/vol12/enb12594e.html', 'Summary')
# ('to be fixed', 608, '2014-12-1', 'https://enb.iisd.org/vol12/enb12608e.html', 'First')
# ('to be fixed', 609, '2014-12-2', 'https://enb.iisd.org/vol12/enb12609e.html', 'Issue')
# ('to be fixed', 610, '2014-12-3', 'https://enb.iisd.org/vol12/enb12610e.html', 'Issue')
# ('to be fixed', 611, '2014-12-4', 'https://enb.iisd.org/vol12/enb12611e.html', 'Issue')
# ('to be fixed', 612, '2014-12-5', 'https://enb.iisd.org/vol12/enb12612e.html', 'Issue')
# ('to be fixed', 613, '2014-12-6', 'https://enb.iisd.org/vol12/enb12613e.html', 'Issue')
# ('to be fixed', 614, '2014-12-8', 'https://enb.iisd.org/vol12/enb12614e.html', 'Issue')
# ('to be fixed', 615, '2014-12-9', 'https://enb.iisd.org/vol12/enb12615e.html', 'Issue')
# ('to be fixed', 616, '2014-12-10', 'https://enb.iisd.org/vol12/enb12616e.html', 'Issue')
# ('to be fixed', 617, '2014-12-11', 'https://enb.iisd.org/vol12/enb12617e.html', 'Issue')
# ('to be fixed', 618, '2014-12-12', 'https://enb.iisd.org/vol12/enb12618e.html', 'Issue')
# ('to be fixed', 619, 'Summary', 'https://enb.iisd.org/vol12/enb12619e.html', 'Summary')
# ('to be fixed', 652, '2015-11-29', 'https://enb.iisd.org/vol12/enb12652e.html', 'First')
# ('to be fixed', 653, '2015-11-30', 'https://enb.iisd.org/vol12/enb12653e.html', 'Issue')
# ('to be fixed', 654, '2015-12-1', 'https://enb.iisd.org/vol12/enb12654e.html', 'Issue')
# ('to be fixed', 655, '2015-12-2', 'https://enb.iisd.org/vol12/enb12655e.html', 'Issue')
# ('to be fixed', 656, '2015-12-3', 'https://enb.iisd.org/vol12/enb12656e.html', 'Issue')
# ('to be fixed', 657, '2015-12-4', 'https://enb.iisd.org/vol12/enb12657e.html', 'Issue')
# ('to be fixed', 658, '2015-12-5', 'https://enb.iisd.org/vol12/enb12658e.html', 'Issue')
# ('to be fixed', 659, '2015-12-7', 'https://enb.iisd.org/vol12/enb12659e.html', 'Issue')
# ('to be fixed', 660, '2015-12-8', 'https://enb.iisd.org/vol12/enb12660e.html', 'Issue')
# ('to be fixed', 661, '2015-12-9', 'https://enb.iisd.org/vol12/enb12661e.html', 'Issue')
# ('to be fixed', 662, '2015-12-10', 'https://enb.iisd.org/vol12/enb12662e.html', 'Issue')
# ('to be fixed', 663, 'Summary and Analysis', 'https://enb.iisd.org/vol12/enb12663e.html', 'Summary')
# ('to be fixed', 678, '2016-11-7', 'https://enb.iisd.org/vol12/enb12678e.html', 'First')
# ('to be fixed', 679, '2016-11-8', 'https://enb.iisd.org/vol12/enb12679e.html', 'Issue')
# ('to be fixed', 680, '2016-11-9', 'https://enb.iisd.org/vol12/enb12680e.html', 'Issue')
# ('to be fixed', 681, '2016-11-10', 'https://enb.iisd.org/vol12/enb12681e.html', 'Issue')
# ('to be fixed', 682, '2016-11-11', 'https://enb.iisd.org/vol12/enb12682e.html', 'Issue')
# ('to be fixed', 683, '2016-11-12', 'https://enb.iisd.org/vol12/enb12683e.html', 'Issue')
# ('to be fixed', 684, '2016-11-14', 'https://enb.iisd.org/vol12/enb12684e.html', 'Issue')
# ('to be fixed', 685, '2016-11-15', 'https://enb.iisd.org/vol12/enb12685e.html', 'Issue')
# ('to be fixed', 686, '2016-11-16', 'https://enb.iisd.org/vol12/enb12686e.html', 'Issue')
# ('to be fixed', 687, '2016-11-17', 'https://enb.iisd.org/vol12/enb12687e.html', 'Issue')
# ('to be fixed', 688, '2016-11-18', 'https://enb.iisd.org/vol12/enb12688e.html', 'Issue')
# ('to be fixed', 689, 'Summary and Analysis', 'https://enb.iisd.org/vol12/enb12689e.html', 'Summary')
# ('to be fixed', 703, '2017-11-6', 'https://enb.iisd.org/vol12/enb12703e.html', 'First')
# ('to be fixed', 704, '2017-11-7', 'https://enb.iisd.org/vol12/enb12704e.html', 'Issue')
# ('to be fixed', 705, '2017-11-8', 'https://enb.iisd.org/vol12/enb12705e.html', 'Issue')
# ('to be fixed', 706, '2017-11-9', 'https://enb.iisd.org/vol12/enb12706e.html', 'Issue')
# ('to be fixed', 707, '2017-11-10', 'https://enb.iisd.org/vol12/enb12707e.html', 'Issue')
# ('to be fixed', 708, '2017-11-11', 'https://enb.iisd.org/vol12/enb12708e.html', 'Issue')
# ('to be fixed', 709, '2017-11-13', 'https://enb.iisd.org/vol12/enb12709e.html', 'Issue')
# ('to be fixed', 710, '2017-11-14', 'https://enb.iisd.org/vol12/enb12710e.html', 'Issue')
# ('to be fixed', 711, '2017-11-15', 'https://enb.iisd.org/vol12/enb12711e.html', 'Issue')
# ('to be fixed', 712, '2017-11-16', 'https://enb.iisd.org/vol12/enb12712e.html', 'Issue')
# ('to be fixed', 713, '2017-11-17', 'https://enb.iisd.org/vol12/enb12713e.html', 'Issue')
# ('to be fixed', 714, 'Summary and Analysis', 'https://enb.iisd.org/vol12/enb12714e.html', 'Summary')
# ('to be fixed', 735, 'Curtain Raiser', 'https://enb.iisd.org/vol12/enb12735e.html', 'First')
# ('to be fixed', 736, '2018-12-2', 'https://enb.iisd.org/vol12/enb12736e.html', 'Issue')
# ('to be fixed', 737, '2018-12-3', 'https://enb.iisd.org/vol12/enb12737e.html', 'Issue')
# ('to be fixed', 738, '2018-12-4', 'https://enb.iisd.org/vol12/enb12738e.html', 'Issue')
# ('to be fixed', 739, '2018-12-5', 'https://enb.iisd.org/vol12/enb12739e.html', 'Issue')
# ('to be fixed', 740, '2018-12-6', 'https://enb.iisd.org/vol12/enb12740e.html', 'Issue')
# ('to be fixed', 741, '2018-12-7', 'https://enb.iisd.org/vol12/enb12741e.html', 'Issue')
# ('to be fixed', 742, '2018-12-8', 'https://enb.iisd.org/vol12/enb12742e.html', 'Issue')
# ('to be fixed', 743, '2018-12-10', 'https://enb.iisd.org/vol12/enb12743e.html', 'Issue')
# ('to be fixed', 744, '2018-12-11', 'https://enb.iisd.org/vol12/enb12744e.html', 'Issue')
# ('to be fixed', 745, '2018-12-12', 'https://enb.iisd.org/vol12/enb12745e.html', 'Issue')
# ('to be fixed', 746, '2018-12-13', 'https://enb.iisd.org/vol12/enb12746e.html', 'Issue')
# ('to be fixed', 747, 'Summary and Analysis', 'https://enb.iisd.org/vol12/enb12747e.html', 'Summary')
# ('to be fixed', 764, 'Curtain Raiser', 'https://enb.iisd.org/vol12/enb12764e.html', 'First')
# ('to be fixed', 765, '2019-12-2', 'https://enb.iisd.org/vol12/enb12765e.html', 'Issue')
# ('to be fixed', 766, '2019-12-3', 'https://enb.iisd.org/vol12/enb12766e.html', 'Issue')
# ('to be fixed', 767, '2019-12-4', 'https://enb.iisd.org/vol12/enb12767e.html', 'Issue')
# ('to be fixed', 768, '2019-12-5', 'https://enb.iisd.org/vol12/enb12768e.html', 'Issue')
# ('to be fixed', 769, '2019-12-6', 'https://enb.iisd.org/vol12/enb12769e.html', 'Issue')
# ('to be fixed', 770, '2019-12-7', 'https://enb.iisd.org/vol12/enb12770e.html', 'Issue')
# ('to be fixed', 771, '2019-12-9', 'https://enb.iisd.org/vol12/enb12771e.html', 'Issue')
# ('to be fixed', 772, '2019-12-10', 'https://enb.iisd.org/vol12/enb12772e.html', 'Issue')
# ('to be fixed', 773, '2019-12-11', 'https://enb.iisd.org/vol12/enb12773e.html', 'Issue')
# ('to be fixed', 774, '2019-12-12', 'https://enb.iisd.org/vol12/enb12774e.html', 'Issue')
# ('to be fixed', 775, 'Summary and Analysis', 'https://enb.iisd.org/vol12/enb12775e.html', 'Summary')
